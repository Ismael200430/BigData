# %% [markdown]
# # Practica 1
# ## Analisis de la evolución población mundial
# ### Actividad 1- identificaión de la fuente
#
# **Cita**
# >UN, World Population Prospects (2024) – processed by Our World in Data. “Annual change in population – UN WPP” [dataset]. United Nations, “World Population Prospects”; United Nations, “World Population Prospects - Interim Update” [original data].
#
# **Preguntas**
#
# Responde brevemente:
#
# 1.¿Quién produjo originalmente los datos? United Nations
#
# 2.¿Qué organización los procesa para su utilización en Our World in Data? Our World in Data
#
# 3.¿Qué representa la variable que analizarás? Annual population growth

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\Lucy Flores\Documents\BIG_DATA\U1_1_probabilidad_estadistica\data\raw\annual-population-growth/annual-population-growth.csv')
df
# Out:
#             Entity Code  Year  Annual change in population  \
# 0      Afghanistan  AFG  1951                     103163.0
# 1      Afghanistan  AFG  1952                     108441.0
# 2      Afghanistan  AFG  1953                     108919.0
# 3      Afghanistan  AFG  1954                     111251.0
# 4      Afghanistan  AFG  1955                     119027.0
# ...            ...  ...   ...                          ...
# 38395     Zimbabwe  ZWE  2096                          NaN
# 38396     Zimbabwe  ZWE  2097                          NaN
# 38397     Zimbabwe  ZWE  2098                          NaN
# 38398     Zimbabwe  ZWE  2099                          NaN
# 38399     Zimbabwe  ZWE  2100                          NaN
#
#        Annual population change (Projected)
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# ...

# %%
df.head(3)
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN

# %%
df.isnull().sum()
# Out:
# Entity                                      0
# Code                                     1200
# Year                                        0
# Annual change in population             19712
# Annual population change (Projected)    18688
# dtype: int64

# %%
df["Entity"].nunique()
# Out:
# 256

# %%
df_extraccion_entity = df[["Entity", "Year"]]
df_extraccion_entity.head(3)
# Out:
#         Entity  Year
# 0  Afghanistan  1951
# 1  Afghanistan  1952
# 2  Afghanistan  1953

# %%
df_2020 = df[df["Year"] == 2020]
df_2020.head(3)
# Out:
#           Entity    Code  Year  Annual change in population  \
# 69   Afghanistan     AFG  2020                    1212852.0
# 219  Africa (UN)  UN_AFR  2020                   32815675.0
# 369      Albania     ALB  2020                     -13061.0
#
#      Annual population change (Projected)
# 69                                    NaN
# 219                                   NaN
# 369                                   NaN

# %%
df_2020_ext_col1 = df_2020[["Entity","Year"]]
df_2020_ext_col1.head(3)
df_2020_ext_col2 = df[df["Year"] == 2020][["Entity", "Year"]]
df_2020_ext_col2.head(3)
# Out:
#           Entity  Year
# 69   Afghanistan  2020
# 219  Africa (UN)  2020
# 369      Albania  2020

# %%
df_2005_2020 = df[(df["Year"] >= 2005) & (df["Year"] <= 2020) & (df["Entity"] == "Mexico")]
df_2005_2020.head()
# Out:
#        Entity Code  Year  Annual change in population  \
# 22254  Mexico  MEX  2005                    1417373.0
# 22255  Mexico  MEX  2006                    1442162.0
# 22256  Mexico  MEX  2007                    1520690.0
# 22257  Mexico  MEX  2008                    1599930.0
# 22258  Mexico  MEX  2009                    1625434.0
#
#        Annual population change (Projected)
# 22254                                   NaN
# 22255                                   NaN
# 22256                                   NaN
# 22257                                   NaN
# 22258                                   NaN

# %%
df_ext_entiAnual = df_2005_2020[["Entity", "Annual change in population"]]
df_ext_entiAnual
# Out:
#        Entity  Annual change in population
# 22254  Mexico                    1417373.0
# 22255  Mexico                    1442162.0
# 22256  Mexico                    1520690.0
# 22257  Mexico                    1599930.0
# 22258  Mexico                    1625434.0
# 22259  Mexico                    1624178.0
# 22260  Mexico                    1619605.0
# 22261  Mexico                    1574705.0
# 22262  Mexico                    1525364.0
# 22263  Mexico                    1440693.0
# 22264  Mexico                    1288045.0
# 22265  Mexico                    1179034.0
# 22266  Mexico                    1148708.0
# 22267  Mexico                    1173661.0
# 22268  Mexico                    1189265.0
# 22269  Mexico                    1036075.0

# %%
df_ext_entiAnual.mean(numeric_only=True)
# Out:
# Annual change in population    1400307.625
# dtype: float64

# %%
df["Entity"].nunique()
# Out:
# 256

# %%
df_n = df[df["Entity"].str.startswith("R")]
df_n
# Out:
#         Entity Code  Year  Annual change in population  \
# 28200  Reunion  REU  1951                       9292.0
# 28201  Reunion  REU  1952                       9677.0
# 28202  Reunion  REU  1953                      10116.0
# 28203  Reunion  REU  1954                      10829.0
# 28204  Reunion  REU  1955                      11294.0
# ...        ...  ...   ...                          ...
# 28795   Rwanda  RWA  2096                          NaN
# 28796   Rwanda  RWA  2097                          NaN
# 28797   Rwanda  RWA  2098                          NaN
# 28798   Rwanda  RWA  2099                          NaN
# 28799   Rwanda  RWA  2100                          NaN
#
#        Annual population change (Projected)
# 28200                                   NaN
# 28201                                   NaN
# 28202                                   NaN
# 28203                                   NaN
# 28204                                   NaN
# ...

# %%
df_1983_2021 = df[(df["Year"] >= 1983) & (df["Year"] <= 2021) & (df["Entity"] == "Rwanda")]
df_1983_2021
# Out:
#        Entity Code  Year  Annual change in population  \
# 28682  Rwanda  RWA  1983                     193756.0
# 28683  Rwanda  RWA  1984                     202317.0
# 28684  Rwanda  RWA  1985                     209602.0
# 28685  Rwanda  RWA  1986                     214657.0
# 28686  Rwanda  RWA  1987                     217607.0
# 28687  Rwanda  RWA  1988                     218581.0
# 28688  Rwanda  RWA  1989                     216634.0
# 28689  Rwanda  RWA  1990                     190604.0
# 28690  Rwanda  RWA  1991                     151651.0
# 28691  Rwanda  RWA  1992                     156302.0
# 28692  Rwanda  RWA  1993                     297876.0
# 28693  Rwanda  RWA  1994                   -1188784.0
# 28694  Rwanda  RWA  1995                   -1118240.0
# 28695  Rwanda  RWA  1996                    1034649.0
# 28696  Rwanda  RWA  1997                    1046470.0
# 28697  Rwanda  RWA  1998                     326451.0
# ...

# %%
df_1983_2021.mean(numeric_only=True)
# Out:
# Year                                      2002.000000
# Annual change in population             195992.435897
# Annual population change (Projected)              NaN
# dtype: float64

# %%
df_1983_2021.median(numeric_only=True)
# Out:
# Year                                      2002.0
# Annual change in population             244719.0
# Annual population change (Projected)         NaN
# dtype: float64

# %%
df_1983_2021.var(numeric_only=True)
# Out:
# Year                                    1.300000e+02
# Annual change in population             1.381985e+11
# Annual population change (Projected)             NaN
# dtype: float64

# %%
df_1983_2021.std(numeric_only=True)
# Out:
# Year                                        11.401754
# Annual change in population             371750.603383
# Annual population change (Projected)              NaN
# dtype: float64

# %%
df_1983_2021.min(numeric_only=True)
# Out:
# Year                                       1983.0
# Annual change in population            -1188784.0
# Annual population change (Projected)          NaN
# dtype: float64

# %%
df_1983_2021.max(numeric_only=True)
# Out:
# Year                                       2021.0
# Annual change in population             1046470.0
# Annual population change (Projected)          NaN
# dtype: float64

# %%
df.head()
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.loc[:,"Entity"]
df.iloc[600:610,0:2]
# Out:
#              Entity Code
# 600  American Samoa  ASM
# 601  American Samoa  ASM
# 602  American Samoa  ASM
# 603  American Samoa  ASM
# 604  American Samoa  ASM
# 605  American Samoa  ASM
# 606  American Samoa  ASM
# 607  American Samoa  ASM
# 608  American Samoa  ASM
# 609  American Samoa  ASM

# %%
df.loc[10000]
df.iloc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.loc[:,["Entity", "Year", "Annual change in population"]]
df.iloc[:,[0,1,3]]
# Out:
#             Entity Code  Annual change in population
# 0      Afghanistan  AFG                     103163.0
# 1      Afghanistan  AFG                     108441.0
# 2      Afghanistan  AFG                     108919.0
# 3      Afghanistan  AFG                     111251.0
# 4      Afghanistan  AFG                     119027.0
# ...            ...  ...                          ...
# 38395     Zimbabwe  ZWE                          NaN
# 38396     Zimbabwe  ZWE                          NaN
# 38397     Zimbabwe  ZWE                          NaN
# 38398     Zimbabwe  ZWE                          NaN
# 38399     Zimbabwe  ZWE                          NaN
#
# [38400 rows x 3 columns]

# %%
df.loc[10000,["Entity", "Year"]]
# Out:
# Entity    Equatorial Guinea
# Year                   2051
# Name: 10000, dtype: object

# %%
df.loc[:, ["Entity", "Year"]]
# Out:
#             Entity  Year
# 0      Afghanistan  1951
# 1      Afghanistan  1952
# 2      Afghanistan  1953
# 3      Afghanistan  1954
# 4      Afghanistan  1955
# ...            ...   ...
# 38395     Zimbabwe  2096
# 38396     Zimbabwe  2097
# 38397     Zimbabwe  2098
# 38398     Zimbabwe  2099
# 38399     Zimbabwe  2100
#
# [38400 rows x 2 columns]

# %%
df_2020_mex = df[(df["Year"] == 2020) & (df["Entity"] == "Mexico")]
df_2020_mex.loc[:, ["Entity", "Year"]]
df_2020_mex.iloc[:, [1,2,3,4]]
# Out:
#       Code  Year  Annual change in population  \
# 22269  MEX  2020                    1036075.0
#
#        Annual population change (Projected)
# 22269                                   NaN
